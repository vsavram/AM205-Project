# %% [markdown]
# Meeting Agenda
#  - Timeline
#     - ASAP
#       - get LUNA working and speedy
#       - How to divide up improving LUNA
#          - problems:
#             - finite difference correctness - Max
#             - runtime
#             -
#     - AM 205 Deadline 14th
#       - Intro, Technical, Existing work, Discussion, Implementation
#     - After 14th
#          - Finding Failure
#          - Discussion like broader impact
#          - add any 205 discoveries
#     - Deadline - Dec 18th 11:59
#
# - Michael Unavailable
#    - Dec 13 - Dec16
#
# - Elaine Unavailable
#     - 9th deadline
#     - Dec 12th - Dec 15th
#
# - Max Unavailable
#     - Dec 11 and 12 deadlines
#     - All LUNA post 12th

# %% [markdown]
# Tasks
#  - Final Notebook
#  - Speed Luna/ Correcntess
#  - Luna Experiments
#  - Writing
#     - Intro
#     - Tech
#     - Discussion
#         - Evaluation
#         - Future Work
#         - Broader Impact

# %%
# Start writing code here...
